# %% [markdown]
# <a href="https://colab.research.google.com/github/eduion/DeepRL/blob/main/HW5/HW5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# source paper:https://paperswithcode.com/paper/cleanrl-high-quality-single-file
#
# github:https://github.com/vwxyzjn/cleanrl/tree/master
#
# 我是跑dqn.py，主要用來訓練agent在Gym環境(預設為 CartPole-v1）中透過學習最大化回報。
#
# 我訓練了 50 萬個 step，從下方圖表可以看出：
#
# charts/episodic_return：隨訓練進行回報穩定上升，代表 agent 表現越來越好
#
# losses/td_loss：TD 誤差逐漸下降，表示學習穩定
#
# charts/SPS：每秒訓練步數約 2000，顯示訓練效率良好

# %% [markdown]
# ![image.png](data:image/png;base64,...)
